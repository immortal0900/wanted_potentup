# %%
import pandas as pd

# %%
data = pd.Series(data= [3.0,5.0,7.0,9.0,11.0], index=[0,1,2,3,4] ,dtype = 'float32')
print(data)
# Out:
# 0     3.0
# 1     5.0
# 2     7.0
# 3     9.0
# 4    11.0
# dtype: float64

# %%
import numpy as np
data1 = np.array([1,2.0])
print(type(data1))
# Out:
# <class 'numpy.ndarray'>
