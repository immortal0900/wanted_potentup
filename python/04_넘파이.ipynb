# %% [markdown]
# # 넘파이

# %%
mylist = [1,2,3,4,5]
print(mylist)

# %%
print(mylist * 2)

# %%
from PIL import Image
from IPython.display import display
image = Image.open('C:/Users/user/OneDrive/wanted_potentup/wanted_potentup/image/202401101118406710_1.jpg')
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=650x879>

# %%
uv add pillow # 이거 설치해야 함

# %%
import numpy as np
image_arr = np.array(image)
image_arr
# 폴더를 실행
# png는 투명도까지 있어서 4열
# Out:
# array([[[203, 195, 193],
#         [203, 198, 194],
#         [206, 202, 201],
#         ...,
#         [242, 204, 191],
#         [240, 206, 196],
#         [240, 206, 196]],
#
#        [[197, 196, 191],
#         [200, 197, 190],
#         [203, 198, 194],
#         ...,
#         [243, 207, 193],
#         [240, 206, 194],
#         [240, 206, 194]],
#
#        [[200, 197, 192],
#         [202, 197, 191],
#         [201, 196, 192],
#         ...,
#         [240, 207, 192],
#         [240, 207, 192],
#         [240, 207, 192]],
#
#        ...,
#
#        [[194, 183, 189],
#         [194, 183, 189],
#         [195, 182, 189],
#         ...,
#         [192, 228, 252],
#         [193, 229, 253],
#         [193, 229, 253]],
#
#        [[196, 184, 188],
#         [196, 184, 188],
#         [196, 183, 190],
#         ...,
#         [192, 226, 251],
#         [194, 228, 253],
#         [194, 228, 253]],
#
#        [[195, 183, 187],
#         [195, 183, 187],
#         [196, 183, 190],
# ...

# %%
print(image_arr.shape)
print(image_arr.ndim)
# Out:
# (879, 650, 3)
# 3

# %%
image_arr2 = 255 - image_arr # 반전이 되게 만든것 
#numpy가 있기 때문에 연산이 가능한 것
image2 = Image.fromarray(image_arr2)

display(image2)
# Out:
# <PIL.Image.Image image mode=RGB size=650x879>
